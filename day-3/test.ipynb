# %%
from ex04_langgraph_conditional_edge_demo import create_ticket_processor_graph
from IPython.display import Image, display

app = create_ticket_processor_graph(None)
display(Image(app.get_graph().draw_png()))
